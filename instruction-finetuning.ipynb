# %%
# %pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.51.3-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: filelock in /Users/azeez/miniforge3/lib/python3.10/site-packages (from transformers) (3.16.1)
# Collecting huggingface-hub<1.0,>=0.30.0 (from transformers)
#   Downloading huggingface_hub-0.31.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /Users/azeez/miniforge3/lib/python3.10/site-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Downloading safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Requirement already satisfied: tqdm>=4.27 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.12.2)
# Collecting hf-xet<2.0.0,>=1.1.0 (from huggingface-hub<1.0,>=0.30.0->transformers)
#   Downloading hf_xet-1.1.0-cp37-abi3-macosx_11_0_arm64.whl.metadata (494 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from requests->transformers) (2025.1.31)
# Downloading transformers-4.51.3-py3-none-any.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 2.7 MB/s eta 0:00:0000:0100:01
# Downloading huggingface_hub-0.31.1-py3-none-any.whl (484 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.3/484.3 kB 2.2 MB/s eta 0:00:0000:0100:01
# Downloading safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl (418 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.4/418.4 kB 2.8 MB/s eta 0:00:0000:0100:01
# Downloading tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 2.7 MB/s eta 0:00:00a 0:00:01
# Downloading hf_xet-1.1.0-cp37-abi3-macosx_11_0_arm64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 2.9 MB/s eta 0:00:0000:0100:010m
# Installing collected packages: safetensors, hf-xet, huggingface-hub, tokenizers, transformers
# Successfully installed hf-xet-1.1.0 huggingface-hub-0.31.1 safetensors-0.5.3 tokenizers-0.21.1 transformers-4.51.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /Users/azeez/miniforge3/lib/python3.10/site-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from datasets) (1.26.4)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-20.0.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /Users/azeez/miniforge3/lib/python3.10/site-packages (from datasets) (2.2.3)
# Collecting requests>=2.32.2 (from datasets)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2024.10.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from datasets) (0.31.1)
# Requirement already satisfied: packaging in /Users/azeez/miniforge3/lib/python3.10/site-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.11.18)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from huggingface-hub>=0.24.0->datasets) (4.12.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from huggingface-hub>=0.24.0->datasets) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.0)
# Requirement already satisfied: six>=1.5 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 3.1 MB/s eta 0:00:00a 0:00:01
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 6.6 MB/s eta 0:00:00
# Downloading pyarrow-20.0.0-cp310-cp310-macosx_12_0_arm64.whl (30.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 4.9 MB/s eta 0:00:0000:0100:01
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading xxhash-3.5.0-cp310-cp310-macosx_11_0_arm64.whl (30 kB)
# Installing collected packages: xxhash, requests, pyarrow, dill, multiprocess, datasets
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# Successfully installed datasets-3.6.0 dill-0.3.8 multiprocess-0.70.16 pyarrow-20.0.0 requests-2.32.3 xxhash-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install trl
# Out:
# Collecting trl
#   Downloading trl-0.17.0-py3-none-any.whl.metadata (12 kB)
# Collecting accelerate>=0.34.0 (from trl)
#   Downloading accelerate-1.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: datasets>=3.0.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from trl) (3.6.0)
# Requirement already satisfied: rich in /Users/azeez/miniforge3/lib/python3.10/site-packages (from trl) (13.9.4)
# Requirement already satisfied: transformers>=4.46.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from trl) (4.51.3)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from accelerate>=0.34.0->trl) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from accelerate>=0.34.0->trl) (24.0)
# Requirement already satisfied: psutil in /Users/azeez/miniforge3/lib/python3.10/site-packages (from accelerate>=0.34.0->trl) (6.1.0)
# Requirement already satisfied: pyyaml in /Users/azeez/miniforge3/lib/python3.10/site-packages (from accelerate>=0.34.0->trl) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from accelerate>=0.34.0->trl) (2.4.1.post2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from accelerate>=0.34.0->trl) (0.31.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from accelerate>=0.34.0->trl) (0.5.3)
# Requirement already satisfied: filelock in /Users/azeez/miniforge3/lib/python3.10/site-packages (from datasets>=3.0.0->trl) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from datasets>=3.0.0->trl) (20.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from datasets>=3.0.0->trl) (0.3.8)
# Requirement already satisfied: pandas in /Users/azeez/miniforge3/lib/python3.10/site-packages (from datasets>=3.0.0->trl) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from datasets>=3.0.0->trl) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from datasets>=3.0.0->trl) (4.67.1)
# Requirement already satisfied: xxhash in /Users/azeez/miniforge3/lib/python3.10/site-packages (from datasets>=3.0.0->trl) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from datasets>=3.0.0->trl) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (2024.10.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from transformers>=4.46.0->trl) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from transformers>=4.46.0->trl) (0.21.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from rich->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from rich->trl) (2.18.0)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from rich->trl) (4.12.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (3.11.18)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate>=0.34.0->trl) (1.1.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->trl) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=3.0.0->trl) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=3.0.0->trl) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=3.0.0->trl) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=3.0.0->trl) (2025.1.31)
# Requirement already satisfied: sympy in /Users/azeez/miniforge3/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=0.34.0->trl) (1.13.3)
# Requirement already satisfied: networkx in /Users/azeez/miniforge3/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=0.34.0->trl) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=0.34.0->trl) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from pandas->datasets>=3.0.0->trl) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from pandas->datasets>=3.0.0->trl) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from pandas->datasets>=3.0.0->trl) (2024.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (1.20.0)
# Requirement already satisfied: six>=1.5 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets>=3.0.0->trl) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from jinja2->torch>=2.0.0->accelerate>=0.34.0->trl) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/azeez/miniforge3/lib/python3.10/site-packages (from sympy->torch>=2.0.0->accelerate>=0.34.0->trl) (1.3.0)
# Downloading trl-0.17.0-py3-none-any.whl (348 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.0/348.0 kB 2.0 MB/s eta 0:00:00a 0:00:01m
# Downloading accelerate-1.6.0-py3-none-any.whl (354 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.7/354.7 kB 2.0 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: accelerate, trl
# Successfully installed accelerate-1.6.0 trl-0.17.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ["WANDB_PROJECT"]="tinyllama_instruct_finetuning" 

from enum import Enum 
from functools import partial
import pandas as pd
import torch

from transformers import AutoModelForCausalLM, AutoTokenizer, TrainingArguments
from datasets import load_dataset
from trl import SFTTrainer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniforge3/lib/python3.10/site-packages/tensorflow/python/pywrap_tensorflow.py:70
#      69 try:
# ---> 70   from tensorflow.python._pywrap_tensorflow_internal import *
#      71 # This try catch logic is because there is no bazel equivalent for py_extension.
#      72 # Externally in opensource we must enable exceptions to load the shared object
#      73 # by exposing the PyInit symbols with pybind. This error will only be
#      74 # caught internally or if someone changes the name of the target _pywrap_tensorflow_internal.
#      75
#      76 # This logic is used in other internal projects using py_extension.
#
# ImportError: dlopen(/Users/azeez/miniforge3/lib/python3.10/site-packages/tensorflow/python/_pywrap_tensorflow_internal.so, 0x0006): Symbol not found: __ZN4absl12lts_2024072212log_internal10LogMessagelsIhTnNSt3__19enable_ifIXntsr4absl16HasAbslStringifyIT_EE5valueEiE4typeELi0EEERS2_RKS6_
#   Referenced from: <5C834607-FBDA-3456-9224-73B76A3FFCD9> /Users/azeez/miniforge3/lib/libre2.11.dylib
#   Expected in:     <09AB2232-31E2-334F-95C8-1C59C0A85FF7> /Users/azeez/miniforge3/lib/libabsl_log_internal_message.2407.0.0.dylib
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File ~/miniforge3/lib/python3.10/site-packages/transformers/utils/import_utils.py:1967, in _LazyModule._get_module(self, module_name)
#    1966 try:
# -> 1967     return importlib.import_module("." + module_name, self.__name__)
#    1968 except Exception as e:
#
# File ~/miniforge3/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/miniforge3/lib/python3.10/site-packages/transformers/image_processing_utils.py:22
#      21 from .image_processing_base import BatchFeature, ImageProcessingMixin
# ---> 22 from .image_transforms import center_crop, normalize, rescale
#      23 from .image_utils import ChannelDimension, get_image_size
#
# File ~/miniforge3/lib/python3.10/site-packages/transformers/image_transforms.py:47
#      46 if is_tf_available():
# ---> 47     import tensorflow as tf
#      49 if is_flax_available():
#
# File ~/miniforge3/lib/python3.10/site-packages/tensorflow/__init__.py:38
#      37 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 38 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      39 from tensorflow.python.tools import module_util as _module_util
#
# File ~/miniforge3/lib/python3.10/site-packages/tensorflow/python/pywrap_tensorflow.py:85
#      84 except ImportError:
# ---> 85   raise ImportError(
#      86       f'{traceback.format_exc()}'
#      87       f'\n\nFailed to load the native TensorFlow runtime.\n'
#      88       f'See https://www.tensorflow.org/install/errors '
#      89       f'for some common causes and solutions.\n'
#      90       f'If you need help, create an issue '
#      91       f'at https://github.com/tensorflow/tensorflow/issues '
#      92       f'and include the entire stack trace above this error message.')
#      94 # pylint: enable=wildcard-import,g-import-not-at-top,unused-import,line-too-long
#
# ImportError: Traceback (most recent call last):
#   File "/Users/azeez/miniforge3/lib/python3.10/site-packages/tensorflow/python/pywrap_tensorflow.py", line 70, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: dlopen(/Users/azeez/miniforge3/lib/python3.10/site-packages/tensorflow/python/_pywrap_tensorflow_internal.so, 0x0006): Symbol not found: __ZN4absl12lts_2024072212log_internal10LogMessagelsIhTnNSt3__19enable_ifIXntsr4absl16HasAbslStringifyIT_EE5valueEiE4typeELi0EEERS2_RKS6_
#   Referenced from: <5C834607-FBDA-3456-9224-73B76A3FFCD9> /Users/azeez/miniforge3/lib/libre2.11.dylib
#   Expected in:     <09AB2232-31E2-334F-95C8-1C59C0A85FF7> /Users/azeez/miniforge3/lib/libabsl_log_internal_message.2407.0.0.dylib
#
#
# Failed to load the native TensorFlow runtime.
# See https://www.tensorflow.org/install/errors for some common causes and solutions.
# If you need help, create an issue at https://github.com/tensorflow/tensorflow/issues and include the entire stack trace above this error message.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File ~/miniforge3/lib/python3.10/site-packages/trl/import_utils.py:149, in _LazyModule._get_module(self, module_name)
#     148 try:
# --> 149     return importlib.import_module("." + module_name, self.__name__)
#     150 except Exception as e:
#
# File ~/miniforge3/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/miniforge3/lib/python3.10/site-packages/trl/trainer/sft_trainer.py:28
#      27 from packaging import version
# ---> 28 from transformers import (
#      29     AutoModelForCausalLM,
#      30     AutoTokenizer,
#      31     BaseImageProcessor,
#      32     DataCollator,
#      33     DataCollatorWithFlattening,
#      34     FeatureExtractionMixin,
#      35     PreTrainedModel,
#      36     PreTrainedTokenizerBase,
#      37     ProcessorMixin,
#      38     Trainer,
#      39     TrainingArguments,
#      40     is_wandb_available,
#      41 )
#      42 from transformers.data.data_collator import DataCollatorMixin
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/miniforge3/lib/python3.10/site-packages/transformers/utils/import_utils.py:1955, in _LazyModule.__getattr__(self, name)
#    1954 elif name in self._class_to_module.keys():
# -> 1955     module = self._get_module(self._class_to_module[name])
#    1956     value = getattr(module, name)
#
# File ~/miniforge3/lib/python3.10/site-packages/transformers/utils/import_utils.py:1969, in _LazyModule._get_module(self, module_name)
#    1968 except Exception as e:
# -> 1969     raise RuntimeError(
#    1970         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1971         f" traceback):\n{e}"
#    1972     ) from e
#
# RuntimeError: Failed to import transformers.image_processing_utils because of the following error (look up to see its traceback):
# Traceback (most recent call last):
#   File "/Users/azeez/miniforge3/lib/python3.10/site-packages/tensorflow/python/pywrap_tensorflow.py", line 70, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: dlopen(/Users/azeez/miniforge3/lib/python3.10/site-packages/tensorflow/python/_pywrap_tensorflow_internal.so, 0x0006): Symbol not found: __ZN4absl12lts_2024072212log_internal10LogMessagelsIhTnNSt3__19enable_ifIXntsr4absl16HasAbslStringifyIT_EE5valueEiE4typeELi0EEERS2_RKS6_
#   Referenced from: <5C834607-FBDA-3456-9224-73B76A3FFCD9> /Users/azeez/miniforge3/lib/libre2.11.dylib
#   Expected in:     <09AB2232-31E2-334F-95C8-1C59C0A85FF7> /Users/azeez/miniforge3/lib/libabsl_log_internal_message.2407.0.0.dylib
#
#
# Failed to load the native TensorFlow runtime.
# See https://www.tensorflow.org/install/errors for some common causes and solutions.
# If you need help, create an issue at https://github.com/tensorflow/tensorflow/issues and include the entire stack trace above this error message.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 11
#       9 from transformers import AutoModelForCausalLM, AutoTokenizer, TrainingArguments
#      10 from datasets import load_dataset
# ---> 11 from trl import SFTTrainer
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/miniforge3/lib/python3.10/site-packages/trl/import_utils.py:140, in _LazyModule.__getattr__(self, name)
#     138 elif name in self._class_to_module.keys():
#     139     module = self._get_module(self._class_to_module[name])
# --> 140     value = getattr(module, name)
#     141 else:
#     142     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# File ~/miniforge3/lib/python3.10/site-packages/trl/import_utils.py:139, in _LazyModule.__getattr__(self, name)
#     137     value = self._get_module(name)
#     138 elif name in self._class_to_module.keys():
# --> 139     module = self._get_module(self._class_to_module[name])
#     140     value = getattr(module, name)
#     141 else:
#
# File ~/miniforge3/lib/python3.10/site-packages/trl/import_utils.py:151, in _LazyModule._get_module(self, module_name)
#     149     return importlib.import_module("." + module_name, self.__name__)
#     150 except Exception as e:
# --> 151     raise RuntimeError(
#     152         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#     153         f" traceback):\n{e}"
#     154     ) from e
#
# RuntimeError: Failed to import trl.trainer.sft_trainer because of the following error (look up to see its traceback):
# Failed to import transformers.image_processing_utils because of the following error (look up to see its traceback):
# Traceback (most recent call last):
#   File "/Users/azeez/miniforge3/lib/python3.10/site-packages/tensorflow/python/pywrap_tensorflow.py", line 70, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: dlopen(/Users/azeez/miniforge3/lib/python3.10/site-packages/tensorflow/python/_pywrap_tensorflow_internal.so, 0x0006): Symbol not found: __ZN4absl12lts_2024072212log_internal10LogMessagelsIhTnNSt3__19enable_ifIXntsr4absl16HasAbslStringifyIT_EE5valueEiE4typeELi0EEERS2_RKS6_
#   Referenced from: <5C834607-FBDA-3456-9224-73B76A3FFCD9> /Users/azeez/miniforge3/lib/libre2.11.dylib
#   Expected in:     <09AB2232-31E2-334F-95C8-1C59C0A85FF7> /Users/azeez/miniforge3/lib/libabsl_log_internal_message.2407.0.0.dylib
#
#
# Failed to load the native TensorFlow runtime.
# See https://www.tensorflow.org/install/errors for some common causes and solutions.
# If you need help, create an issue at https://github.com/tensorflow/tensorflow/issues and include the entire stack trace above this error message.
